# %% [markdown]
# <a href="https://colab.research.google.com/github/Mmabatho/Week6_AI_For_Software_Engneering/blob/chris/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Edge AI Prototype: Recyclable Items Classification
# Task 1: Train a lightweight model and convert to TensorFlow Lite

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import os

# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

class RecyclableClassifier:
    def __init__(self, num_classes=4):
        """
        Initialize the recyclable items classifier
        Classes: 0-Plastic, 1-Paper, 2-Metal, 3-Glass
        """
        self.num_classes = num_classes
        self.class_names = ['Plastic', 'Paper', 'Metal', 'Glass']
        self.model = None
        self.tflite_model = None

    def create_model(self, input_shape=(224, 224, 3)):
        """Create a lightweight model based on MobileNetV2"""
        # Load pre-trained MobileNetV2 as base model
        base_model = MobileNetV2(
            weights='imagenet',
            include_top=False,
            input_shape=input_shape
        )

        # Freeze base model layers
        base_model.trainable = False

        # Add custom classification head
        inputs = tf.keras.Input(shape=input_shape)
        x = base_model(inputs, training=False)
        x = GlobalAveragePooling2D()(x)
        x = Dropout(0.2)(x)
        outputs = Dense(self.num_classes, activation='softmax')(x)

        self.model = Model(inputs, outputs)

        # Compile the model
        self.model.compile(
            optimizer=Adam(learning_rate=0.0001),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        return self.model

    def generate_synthetic_data(self, samples_per_class=100):
        """Generate synthetic data for demonstration purposes"""
        print("Generating synthetic training data...")

        # Create synthetic images with different patterns for each class
        X_train = []
        y_train = []
        X_test = []
        y_test = []

        for class_idx in range(self.num_classes):
            # Training data
            for _ in range(samples_per_class):
                # Generate synthetic image with class-specific patterns
                img = np.random.rand(224, 224, 3)

                # Add class-specific patterns
                if class_idx == 0:  # Plastic - add blue tint
                    img[:, :, 2] += 0.3
                elif class_idx == 1:  # Paper - add brown/yellow tint
                    img[:, :, 0] += 0.2
                    img[:, :, 1] += 0.2
                elif class_idx == 2:  # Metal - add silver/gray tint
                    img[:, :, :] += 0.1
                elif class_idx == 3:  # Glass - add transparency effect
                    img = img * 0.8 + 0.2

                img = np.clip(img, 0, 1)
                X_train.append(img)
                y_train.append(class_idx)

            # Test data (20% of training size)
            for _ in range(samples_per_class // 5):
                img = np.random.rand(224, 224, 3)

                # Same class-specific patterns
                if class_idx == 0:
                    img[:, :, 2] += 0.3
                elif class_idx == 1:
                    img[:, :, 0] += 0.2
                    img[:, :, 1] += 0.2
                elif class_idx == 2:
                    img[:, :, :] += 0.1
                elif class_idx == 3:
                    img = img * 0.8 + 0.2

                img = np.clip(img, 0, 1)
                X_test.append(img)
                y_test.append(class_idx)

        # Convert to numpy arrays and shuffle
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        X_test = np.array(X_test)
        y_test = np.array(y_test)

        # Shuffle the data
        train_indices = np.random.permutation(len(X_train))
        test_indices = np.random.permutation(len(X_test))

        X_train = X_train[train_indices]
        y_train = y_train[train_indices]
        X_test = X_test[test_indices]
        y_test = y_test[test_indices]

        print(f"Training data shape: {X_train.shape}")
        print(f"Test data shape: {X_test.shape}")

        return X_train, y_train, X_test, y_test

    def train_model(self, X_train, y_train, X_val, y_val, epochs=10):
        """Train the model"""
        print("Training the model...")

        # Define callbacks
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=3,
            restore_best_weights=True
        )

        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=2,
            min_lr=0.00001
        )

        # Train the model
        history = self.model.fit(
            X_train, y_train,
            batch_size=32,
            epochs=epochs,
            validation_data=(X_val, y_val),
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        return history

    def evaluate_model(self, X_test, y_test):
        """Evaluate model performance"""
        print("Evaluating model performance...")

        # Get predictions
        predictions = self.model.predict(X_test)
        y_pred = np.argmax(predictions, axis=1)

        # Calculate accuracy
        accuracy = np.mean(y_pred == y_test)

        # Print classification report
        print(f"\nTest Accuracy: {accuracy:.4f}")
        print("\nClassification Report:")
        print(classification_report(y_test, y_pred, target_names=self.class_names))

        # Confusion matrix
        cm = confusion_matrix(y_test, y_pred)
        print("\nConfusion Matrix:")
        print(cm)

        return accuracy, y_pred

    def convert_to_tflite(self):
        """Convert the trained model to TensorFlow Lite format"""
        print("Converting model to TensorFlow Lite...")

        # Convert to TensorFlow Lite
        converter = tf.lite.TFLiteConverter.from_keras_model(self.model)

        # Enable optimizations for edge deployment
        converter.optimizations = [tf.lite.Optimize.DEFAULT]

        # Convert the model
        self.tflite_model = converter.convert()

        # Save the TFLite model
        with open('recyclable_classifier.tflite', 'wb') as f:
            f.write(self.tflite_model)

        # Get model sizes
        original_size = os.path.getsize('recyclable_classifier.tflite') / 1024  # KB
        print(f"TensorFlow Lite model size: {original_size:.2f} KB")

        return self.tflite_model

    def test_tflite_model(self, X_test, y_test, num_samples=10):
        """Test the TensorFlow Lite model"""
        print("Testing TensorFlow Lite model...")

        # Load TFLite model and allocate tensors
        interpreter = tf.lite.Interpreter(model_content=self.tflite_model)
        interpreter.allocate_tensors()

        # Get input and output tensors
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()

        # Test on a subset of test data
        correct_predictions = 0

        for i in range(min(num_samples, len(X_test))):
            # Prepare input data
            input_data = np.expand_dims(X_test[i].astype(np.float32), axis=0)

            # Set input tensor
            interpreter.set_tensor(input_details[0]['index'], input_data)

            # Run inference
            interpreter.invoke()

            # Get output
            output_data = interpreter.get_tensor(output_details[0]['index'])
            prediction = np.argmax(output_data[0])

            if prediction == y_test[i]:
                correct_predictions += 1

            print(f"Sample {i+1}: True={self.class_names[y_test[i]]}, "
                  f"Predicted={self.class_names[prediction]}")

        tflite_accuracy = correct_predictions / num_samples
        print(f"\nTensorFlow Lite Model Accuracy: {tflite_accuracy:.4f}")

        return tflite_accuracy

def main():
    """Main execution function"""
    print("=== Edge AI Prototype: Recyclable Items Classification ===\n")

    # Initialize classifier
    classifier = RecyclableClassifier()

    # Create the model
    model = classifier.create_model()
    print("Model architecture:")
    model.summary()

    # Generate synthetic data
    X_train, y_train, X_test, y_test = classifier.generate_synthetic_data(
        samples_per_class=200
    )

    # Train the model
    history = classifier.train_model(X_train, y_train, X_test, y_test, epochs=15)

    # Evaluate the model
    accuracy, predictions = classifier.evaluate_model(X_test, y_test)

    # Convert to TensorFlow Lite
    tflite_model = classifier.convert_to_tflite()

    # Test TensorFlow Lite model
    tflite_accuracy = classifier.test_tflite_model(X_test, y_test, num_samples=20)

    # Print summary
    print("\n" + "="*50)
    print("DEPLOYMENT SUMMARY")
    print("="*50)
    print(f"Original Model Accuracy: {accuracy:.4f}")
    print(f"TensorFlow Lite Model Accuracy: {tflite_accuracy:.4f}")
    print(f"Model file: recyclable_classifier.tflite")
    print("\nEdge AI Benefits:")
    print("1. Real-time inference without internet connection")
    print("2. Reduced latency (no cloud communication)")
    print("3. Enhanced privacy (data stays on device)")
    print("4. Lower bandwidth usage")
    print("5. Reliable operation in remote areas")

if __name__ == "__main__":
    main()

# Additional utility functions for Edge AI deployment

def simulate_edge_deployment():
    """Simulate deployment on edge device (like Raspberry Pi)"""
    print("\n=== Simulating Edge Device Deployment ===")

    # Simulate loading model on edge device
    print("Loading TensorFlow Lite model on edge device...")

    # Simulate real-time inference
    print("Simulating real-time camera input...")

    # Mock camera input
    camera_input = np.random.rand(224, 224, 3)

    # Load and run inference
    interpreter = tf.lite.Interpreter(model_path='recyclable_classifier.tflite')
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # Preprocess input
    input_data = np.expand_dims(camera_input.astype(np.float32), axis=0)

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()

    # Get results
    output_data = interpreter.get_tensor(output_details[0]['index'])
    prediction = np.argmax(output_data[0])
    confidence = np.max(output_data[0])

    class_names = ['Plastic', 'Paper', 'Metal', 'Glass']
    print(f"Detected: {class_names[prediction]} (Confidence: {confidence:.2f})")
    print("Processing time: ~50ms (typical for edge device)")

# Run the main program
if __name__ == "__main__":
    main()
    simulate_edge_deployment()
# Out:
# === Edge AI Prototype: Recyclable Items Classification ===
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model architecture:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,108 (8.63 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Generating synthetic training data...
# Training data shape: (800, 224, 224, 3)
# Test data shape: (160, 224, 224, 3)
# Training the model...
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 32s 935ms/step - accuracy: 0.2174 - loss: 2.1211 - val_accuracy: 0.2062 - val_loss: 1.5978 - learning_rate: 1.0000e-04
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 895ms/step - accuracy: 0.2396 - loss: 1.7218 - val_accuracy: 0.2375 - val_loss: 1.4024 - learning_rate: 1.0000e-04
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - accuracy: 0.2409 - loss: 1.6099 - val_accuracy: 0.3750 - val_loss: 1.3514 - learning_rate: 1.0000e-04
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 868ms/step - accuracy: 0.2899 - loss: 1.4652 - val_accuracy: 0.4375 - val_loss: 1.3081 - learning_rate: 1.0000e-04
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 894ms/step - accuracy: 0.2907 - loss: 1.4656 - val_accuracy: 0.5188 - val_loss: 1.2669 - learning_rate: 1.0000e-04
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 863ms/step - accuracy: 0.3188 - loss: 1.4328 - val_accuracy: 0.7188 - val_loss: 1.2253 - learning_rate: 1.0000e-04
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 852ms/step - accuracy: 0.3589 - loss: 1.3804 - val_accuracy: 0.7563 - val_loss: 1.1868 - learning_rate: 1.0000e-04
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 804ms/step - accuracy: 0.3586 - loss: 1.3359 - val_accuracy: 0.7750 - val_loss: 1.1491 - learning_rate: 1.0000e-04
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 857ms/step - accuracy: 0.4239 - loss: 1.2254 - val_accuracy: 0.7875 - val_loss: 1.1141 - learning_rate: 1.0000e-04
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 861ms/step - accuracy: 0.3851 - loss: 1.2680 - val_accuracy: 0.8125 - val_loss: 1.0801 - learning_rate: 1.0000e-04
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 865ms/step - accuracy: 0.4385 - loss: 1.2099 - val_accuracy: 0.8250 - val_loss: 1.0472 - learning_rate: 1.0000e-04
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 879ms/step - accuracy: 0.5320 - loss: 1.1463 - val_accuracy: 0.8500 - val_loss: 1.0159 - learning_rate: 1.0000e-04
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 863ms/step - accuracy: 0.4680 - loss: 1.1995 - val_accuracy: 0.8687 - val_loss: 0.9864 - learning_rate: 1.0000e-04
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 868ms/step - accuracy: 0.4987 - loss: 1.1462 - val_accuracy: 0.9125 - val_loss: 0.9584 - learning_rate: 1.0000e-04
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 864ms/step - accuracy: 0.5526 - loss: 1.0615 - val_accuracy: 0.9062 - val_loss: 0.9308 - learning_rate: 1.0000e-04
# Evaluating model performance...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 615ms/step
#
# Test Accuracy: 0.9125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Plastic       0.87      1.00      0.93        40
#        Paper       1.00      0.80      0.89        40
#        Metal       0.81      0.85      0.83        40
#        Glass       1.00      1.00      1.00        40
#
#     accuracy                           0.91       160
#    macro avg       0.92      0.91      0.91       160
# weighted avg       0.92      0.91      0.91       160
#
#
# Confusion Matrix:
# [[40  0  0  0]
#  [ 0 32  8  0]
#  [ 6  0 34  0]
#  [ 0  0  0 40]]
# Converting model to TensorFlow Lite...
# Saved artifact at '/tmp/tmp28409awc'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   139070670703888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670704464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670707728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670707344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670706192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670707920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670706960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670704080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670708112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670705616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670710032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670706768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670706576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670709072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670713872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670712912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670711760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670714256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070670715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663738576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663737424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663738768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663737616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663740112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663740496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663740880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663740688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663738960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663742032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663742416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663742800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663742608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663738192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663739728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663744528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663744912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663744720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663741264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663743568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663746640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663747024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663743952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663748560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663745680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663747792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664114832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664115216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070663749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664116752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664117136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664114256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664119056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664120592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664115984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664122128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664122512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664122896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664122704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664124048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664124432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664124816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664121744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664128656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664123664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664129808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664127504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664524048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664525392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664525776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664525584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664524240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664526928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664527312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664527696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664527504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664524816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664528848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664529232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664529616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664525008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664530768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664526544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664532688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664528464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070676898768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664531920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664538640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664539024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620844304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620845072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070664537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620846032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620846416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620846608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620845264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620847952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620848336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620848720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620844112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620849872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620850256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620850640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620845648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620851792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620852176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620852560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620852368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620847568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620853712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620854096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620854480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620854288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620849488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620855632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620856016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620856400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620856208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620851408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620857552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620857936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620858320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620858128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620853328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620859472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620859088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620858704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620860048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620855248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070620857168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621238672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621237520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621240208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621240592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621242128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621242512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621242704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621238288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621244048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621244432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621244816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621244624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621245968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621246352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621246736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621246544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621247888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621248272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621248656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621248464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621243664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621249808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621250192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621250576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621250384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621245584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621251728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621252112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621252496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621252304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621247504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621249424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621615120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621614160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621251344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621250960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621616464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621616848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621614544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621618000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621618384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621618768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621618576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621615312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621619920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621620304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621620688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621620496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621615696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621621840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621622224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621622608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621622416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621617616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621623376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070621625104: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TensorFlow Lite model size: 2452.37 KB
# Testing TensorFlow Lite model...
# Sample 1: True=Plastic, Predicted=Plastic
# Sample 2: True=Glass, Predicted=Glass
# Sample 3: True=Paper, Predicted=Paper
# Sample 4: True=Metal, Predicted=Plastic
# Sample 5: True=Metal, Predicted=Plastic
# Sample 6: True=Plastic, Predicted=Plastic
# Sample 7: True=Metal, Predicted=Metal
# Sample 8: True=Metal, Predicted=Plastic
# Sample 9: True=Metal, Predicted=Metal
# Sample 10: True=Metal, Predicted=Plastic
# Sample 11: True=Paper, Predicted=Metal
# Sample 12: True=Plastic, Predicted=Plastic
# Sample 13: True=Paper, Predicted=Paper
# Sample 14: True=Metal, Predicted=Plastic
# Sample 15: True=Paper, Predicted=Paper
# Sample 16: True=Paper, Predicted=Metal
# Sample 17: True=Paper, Predicted=Metal
# Sample 18: True=Metal, Predicted=Plastic
# Sample 19: True=Glass, Predicted=Paper
# Sample 20: True=Metal, Predicted=Plastic
#
# TensorFlow Lite Model Accuracy: 0.4500
#
# ==================================================
# DEPLOYMENT SUMMARY
# ==================================================
# Original Model Accuracy: 0.9125
# TensorFlow Lite Model Accuracy: 0.4500
# Model file: recyclable_classifier.tflite
#
# Edge AI Benefits:
# 1. Real-time inference without internet connection
# 2. Reduced latency (no cloud communication)
# 3. Enhanced privacy (data stays on device)
# 4. Lower bandwidth usage
# 5. Reliable operation in remote areas
# === Edge AI Prototype: Recyclable Items Classification ===
#
# Model architecture:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,108 (8.63 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Generating synthetic training data...
# Training data shape: (800, 224, 224, 3)
# Test data shape: (160, 224, 224, 3)
# Training the model...
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.2515 - loss: 2.3387 - val_accuracy: 0.2562 - val_loss: 1.8037 - learning_rate: 1.0000e-04
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 32s 793ms/step - accuracy: 0.2358 - loss: 1.8756 - val_accuracy: 0.2562 - val_loss: 1.5245 - learning_rate: 1.0000e-04
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 879ms/step - accuracy: 0.2508 - loss: 1.6050 - val_accuracy: 0.2750 - val_loss: 1.4347 - learning_rate: 1.0000e-04
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 877ms/step - accuracy: 0.2262 - loss: 1.5805 - val_accuracy: 0.2688 - val_loss: 1.3884 - learning_rate: 1.0000e-04
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 0.2524 - loss: 1.5507 - val_accuracy: 0.3250 - val_loss: 1.3458 - learning_rate: 1.0000e-04
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 859ms/step - accuracy: 0.2645 - loss: 1.4766 - val_accuracy: 0.3688 - val_loss: 1.3040 - learning_rate: 1.0000e-04
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 856ms/step - accuracy: 0.3005 - loss: 1.4801 - val_accuracy: 0.4375 - val_loss: 1.2614 - learning_rate: 1.0000e-04
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 858ms/step - accuracy: 0.3269 - loss: 1.3744 - val_accuracy: 0.5500 - val_loss: 1.2221 - learning_rate: 1.0000e-04
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 882ms/step - accuracy: 0.3466 - loss: 1.3286 - val_accuracy: 0.6000 - val_loss: 1.1850 - learning_rate: 1.0000e-04
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 861ms/step - accuracy: 0.3841 - loss: 1.3210 - val_accuracy: 0.6812 - val_loss: 1.1473 - learning_rate: 1.0000e-04
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 786ms/step - accuracy: 0.3772 - loss: 1.3467 - val_accuracy: 0.7063 - val_loss: 1.1112 - learning_rate: 1.0000e-04
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 863ms/step - accuracy: 0.4238 - loss: 1.2360 - val_accuracy: 0.7437 - val_loss: 1.0765 - learning_rate: 1.0000e-04
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 789ms/step - accuracy: 0.4290 - loss: 1.2231 - val_accuracy: 0.7688 - val_loss: 1.0438 - learning_rate: 1.0000e-04
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 867ms/step - accuracy: 0.4370 - loss: 1.1977 - val_accuracy: 0.7937 - val_loss: 1.0117 - learning_rate: 1.0000e-04
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 876ms/step - accuracy: 0.5157 - loss: 1.1351 - val_accuracy: 0.8250 - val_loss: 0.9818 - learning_rate: 1.0000e-04
# Evaluating model performance...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 607ms/step
#
# Test Accuracy: 0.8250
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Plastic       0.82      1.00      0.90        40
#        Paper       0.80      0.70      0.75        40
#        Metal       0.67      0.60      0.63        40
#        Glass       1.00      1.00      1.00        40
#
#     accuracy                           0.82       160
#    macro avg       0.82      0.82      0.82       160
# weighted avg       0.82      0.82      0.82       160
#
#
# Confusion Matrix:
# [[40  0  0  0]
#  [ 0 28 12  0]
#  [ 9  7 24  0]
#  [ 0  0  0 40]]
# Converting model to TensorFlow Lite...
# Saved artifact at '/tmp/tmprm8cz9nv'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_313')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   139070461595472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461597200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461597008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461595664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461598352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461598736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461599120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461598928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461600272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461600656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461596432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461602192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461602576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461602960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461602768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461597968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461604112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461604496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461604880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461604688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461599888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461606032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461606416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461606800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461606608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461601808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461607184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468801168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461607568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461605648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468802896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468804240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468804624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468805008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468804816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468806160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468806544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468806928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468806736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468808080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468808464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468808848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468808656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468803856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468810000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468810384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468810768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468810576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468805776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468811920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468812304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468812688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468812496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468813840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468814224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468814608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468814416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468809616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468815760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468815376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468813456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468816336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468811536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070468814992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461461904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461463632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461464016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461463824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461462864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461470928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461470544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459085456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070461474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459086608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459086992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459087376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459085840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459088528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459089296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459089104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459084880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459090448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459090832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459091216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459086224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459092368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459092944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459088144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459094288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459094672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459095056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459094864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459096208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459096592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459096976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459096784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459091984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459098512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459098704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459100048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459099664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459097744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459095824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459099280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459762960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459763920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459763344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459765072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459765456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459765648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459766992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459767376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459767760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459767568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459768912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459769296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459769680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459769488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459764688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459770832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459771216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459771600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459771408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459766608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459772752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459768528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459772368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070459770448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460282640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460283024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460283408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460283216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460281872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460284944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460285136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460281296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460286864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460287056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460282256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460289168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460288976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460290320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460290704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460290896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460286096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460292240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460292624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460293008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460292816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460288016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460294160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460294544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460294928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460294736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460289936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460296080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460295696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460293776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460296656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460291856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460295312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460642512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460641552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460642320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460641360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460644048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460644432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460644816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460644624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460641744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460645968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460646736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460642128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139070460648848: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TensorFlow Lite model size: 2452.82 KB
# Testing TensorFlow Lite model...
# Sample 1: True=Plastic, Predicted=Plastic
# Sample 2: True=Metal, Predicted=Plastic
# Sample 3: True=Metal, Predicted=Plastic
# Sample 4: True=Paper, Predicted=Paper
# Sample 5: True=Paper, Predicted=Paper
# Sample 6: True=Glass, Predicted=Glass
# Sample 7: True=Glass, Predicted=Glass
# Sample 8: True=Glass, Predicted=Plastic
# Sample 9: True=Glass, Predicted=Plastic
# Sample 10: True=Plastic, Predicted=Plastic
# Sample 11: True=Plastic, Predicted=Plastic
# Sample 12: True=Paper, Predicted=Paper
# Sample 13: True=Glass, Predicted=Plastic
# Sample 14: True=Paper, Predicted=Plastic
# Sample 15: True=Paper, Predicted=Paper
# Sample 16: True=Plastic, Predicted=Plastic
# Sample 17: True=Metal, Predicted=Plastic
# Sample 18: True=Glass, Predicted=Plastic
# Sample 19: True=Paper, Predicted=Paper
# Sample 20: True=Metal, Predicted=Plastic
#
# TensorFlow Lite Model Accuracy: 0.5500
#
# ==================================================
# DEPLOYMENT SUMMARY
# ==================================================
# Original Model Accuracy: 0.8250
# TensorFlow Lite Model Accuracy: 0.5500
# Model file: recyclable_classifier.tflite
#
# Edge AI Benefits:
# 1. Real-time inference without internet connection
# 2. Reduced latency (no cloud communication)
# 3. Enhanced privacy (data stays on device)
# 4. Lower bandwidth usage
# 5. Reliable operation in remote areas
#
# === Simulating Edge Device Deployment ===
# Loading TensorFlow Lite model on edge device...
# Simulating real-time camera input...
# Detected: Plastic (Confidence: 0.33)
# Processing time: ~50ms (typical for edge device)
